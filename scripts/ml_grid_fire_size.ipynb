# %% [markdown]
# # Predicting regional fire sizes from observed and predicted fire frequencies
#
# Authors: Jatan Buch (v1, 220118) || (v2, 220303) || (v3, 220407) || (v4, 220607) || (v5, 220718)

# %% [markdown]
# ## 1. Packages

# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
#from time import clock
from datetime import date, datetime, timedelta
from cftime import num2date, date2num, DatetimeGregorian
from tqdm import tqdm
from copy import deepcopy

#Import and write files
import csv
import netCDF4 # module that reads in .nc files (built on top of HDF5 format)
import pandas as pd
import geopandas as gpd
from geopandas.tools import sjoin
import xarray
import rioxarray

from shapely.geometry import Point, mapping
from shapely.geometry.polygon import Polygon
from pyproj import CRS, Transformer # for transforming projected coordinates to elliptical coordinates
import cartopy.crs as ccrs # for defining and transforming coordinate systems
import cartopy.feature as cfeature # to add features to a cartopy map
import cartopy.io.shapereader as shpreader

#self-libraries
from fire_utils import *
from ml_utils import *

#Helper functions
from math import factorial
from scipy import stats
from scipy.special import gamma
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.exceptions import NotFittedError
from tensorflow.python import ops
from tensorflow.python import debug as tf_debug

#Plot modules
import matplotlib.pyplot as plt
# %matplotlib inline
# %config IPython.matplotlib.backend = 'retina'
# %config InlineBackend.figure_format = 'retina'

#Stats modules
from scipy import stats
from scipy.stats import norm, pareto, genpareto
import statsmodels.api as sm
from scipy import stats, interpolate
from scipy.optimize import minimize

# Data processing
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split

#modules for Machine Learning
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.linear_model import LinearRegression
import shap

#modules for Neural Network
import tensorflow as tf
import tensorflow_probability as tfp
tfd= tfp.distributions
from tensorflow.keras.layers import Input, Dense, Activation, Concatenate
from tensorflow.keras.callbacks import EarlyStopping, TensorBoard, ReduceLROnPlateau

# %% [markdown]
# ### Extreme weather plots

# %%
fire_scaled_df= pd.read_hdf('../data/clim_fire_size_12km_w2020_rescaled_data.h5')
fire_df= pd.read_hdf('../data/clim_fire_size_12km_w2020_data.h5')

# %% [markdown]
# ## 2. Data preprocessing

# %%
data_dir= "../data/"
fire_file= data_dir + "burnarea_12km.nc"
shap_flag= True #set True if performing SHAP analysis
if shap_flag:
    scaled_flag= True
else:
    scaled_flag= False

n_features= 46
start_month= 420 #372
tot_test_months= 12
end_month= start_month + tot_test_months

# %%
X_sizes_train, X_sizes_val, y_sizes_train, y_sizes_val, fire_size_train, fire_size_test, X_sizes_test, y_sizes_test= fire_size_data(res= '12km', \
                            dropcols= drop_col_func(mod_type= 'normal', add_var_flag= True, add_var_list= ['Delta_T', 'Lightning']), \
                            start_month= start_month, tot_test_months= tot_test_months, threshold= 4, scaled= scaled_flag, tflag= True) #tflag= True; scaled= True, rh_flag= True
#total fires < 18646 while using scaled flag == True because there are grid cells with NaN scaling, especially when including SWE predictors

X_sizes_train_df= pd.concat([X_sizes_train, X_sizes_val], sort= False).reset_index().drop(columns=['index'])
X_sizes_tot= pd.concat([X_sizes_train_df, X_sizes_test], sort= False).reset_index().drop(columns=['index'])
fire_size_tot= pd.concat([fire_size_train, fire_size_test], sort= False).reset_index().drop(columns=['index'])

fire_size_arr= np.concatenate([y_sizes_train, y_sizes_val]) #, y_sizes_test
#empcdf_sizes= tfd.Empirical(np.sort(fire_size_arr)) 
#kde_density= stats.gaussian_kde(fire_size_arr, bw_method= "silverman")
eff_freq_func= sampling_func(y_sizes_train)
norm_fac= 1e-6
samp_weight_arr= norm_fac/eff_freq_func(y_sizes_train)  #empcdf_sizes.cdf(y_sizes_train) #kde_density.evaluate(y_sizes_train) eff_freq_func(y_sizes_train)
# Out:
# 100%|██████████| 17378/17378 [00:48<00:00, 361.22it/s]
# 100%|██████████| 317/317 [00:01<00:00, 252.94it/s]

# %%
nregions= 18
max_fire_train_arr= []
sum_fire_train_arr= []

for r in tqdm(range(nregions)):
    max_fire_train_arr.append(np.max(np.concatenate([fire_size_train.groupby('reg_indx').get_group(r+1).groupby('fire_month').get_group(k).fire_size.to_numpy()/1e6 \
                                    for k in fire_size_train.groupby('reg_indx').get_group(r+1).groupby('fire_month').groups.keys()])))
    #sum_fire_train_arr.append(np.max([np.sum(fire_size_train.groupby('reg_indx').get_group(r+1).groupby('fire_month').get_group(k).fire_size.to_numpy()/1e6) \
    #                                for k in fire_size_train.groupby('reg_indx').get_group(r+1).groupby('fire_month').groups.keys()]))
    
max_fire_train_arr= np.asarray(max_fire_train_arr)
sum_fire_train_arr= max_fire_size_sum_func(fire_size_df= fire_size_tot, final_month= 444) #np.asarray(sum_fire_train_arr)
# Out:
# 100%|██████████| 18/18 [00:07<00:00,  2.32it/s]

# %%
if not shap_flag:
    clim_df= pd.read_hdf('../data/clim_fire_freq_12km_w2020_data.h5') #w2020_rescaled_ --> for SHAP analysis
else:
    clim_df= pd.read_hdf('../data/clim_fire_freq_12km_w2020_rescaled_data.h5')
clim_df.loc[clim_df[clim_df.fire_freq > 1].index, 'fire_freq']= np.ones(len(clim_df[clim_df.fire_freq > 1].index), dtype= np.int64) #sets all non-zero frequencies to 1
#clim_df= clim_df[clim_df.reg_indx != 0].reset_index().drop(columns= ['index']) #needs to match the config in ml_grid_model to ensure proper indexing for freq locations
clim_df= clim_df.dropna().reset_index().drop(columns=['index'])

fire_freq_test_df= clim_df[(clim_df.month >= start_month) & (clim_df.month < end_month)]
fire_freq_train_df= clim_df.drop(fire_freq_test_df.index)

tmp_freq_df= clim_df[clim_df.iloc[:, 0:n_features].columns]
X_freq_df= pd.DataFrame({})
scaler= StandardScaler().fit(fire_freq_train_df.iloc[:, 0:n_features])
X_freq_df[tmp_freq_df.columns]= scaler.transform(tmp_freq_df) #size_scaler

# %%
X_train_tot= X_freq_df.iloc[fire_freq_train_df.index]
X_train_tot.loc[:, 'reg_indx']= fire_freq_train_df.reg_indx
X_train_tot.loc[:, 'month']= fire_freq_train_df.month
X_train_tot= X_train_tot.reset_index().drop(columns=['index', 'Solar', 'Ant_Tmax', 'RH', 'Ant_RH', 'RH_min3', 'FFWI_max7', 'Avgprec_4mo', 'Avgprec_2mo', 'Camp_num', \
                                    'AvgVPD_4mo', 'AvgVPD_2mo', 'Tmax_max7', 'VPD_max7', 'Tmin_max7', 'Elev', 'Delta_T', 'Lightning']) #'RH', 'Ant_RH', 'RH_min3'
X_test_df= X_freq_df.iloc[fire_freq_test_df.index]
X_test_df.loc[:, 'reg_indx']= fire_freq_test_df.reg_indx
X_test_df.loc[:, 'month']= fire_freq_test_df.month
X_test_df= X_test_df.reset_index().drop(columns=['index', 'Solar', 'Ant_Tmax', 'RH', 'Ant_RH', 'RH_min3', 'FFWI_max7', 'Avgprec_4mo', 'Avgprec_2mo', 'Camp_num', \
                                    'AvgVPD_4mo', 'AvgVPD_2mo', 'Tmax_max7', 'VPD_max7', 'Tmin_max7', 'Elev', 'Delta_T', 'Lightning'])

X_freq_tot= pd.concat([X_train_tot, X_test_df], sort= False).reset_index().drop(columns=['index'])
fire_freq_tot= pd.concat([fire_freq_train_df, fire_freq_test_df], sort= False).reset_index().drop(columns=['index'])

# %% [markdown]
# ## 3. MDN fire size model

# %% [markdown]
# ### 3.1 Loading saved fire frequency models

# %%
run_id, it, bs, p_frac= ['05_30_22', None, 8192, '0.3'] #['03_01_22', 12, 8192, '0.3'] #['02_27_22', 2, 8192, '0.3'] #['04_16_22', 2, 8192, '0.3']

if it == None:
    freq_loc_df= pd.read_hdf('../sav_files/fire_freq_pred_dfs/freq_ds_loc_df_%s.h5'%run_id)
    mdn_freq_df=pd.read_hdf('../sav_files/fire_freq_pred_dfs/mdn_ds_mon_fire_freq_%s.h5'%run_id) 
else:
    freq_loc_df= pd.read_hdf('../sav_files/fire_freq_pred_dfs/freq_loc_df_%s'%run_id + '_%s'%bs + '_pfrac_%s'%str(p_frac) + '_iter_run_%d.h5'%it)
    mdn_freq_df= pd.read_hdf('../sav_files/fire_freq_pred_dfs/mdn_mon_fire_freq_%s'%run_id + '_it_%d'%it + '_%d_'%bs + '%s.h5'%str(p_frac)) 
mdn_mon_freq_df, mdn_ann_freq_df= calib_freq_predict(ml_freq_df= mdn_freq_df, n_regs= 18, tot_months= 444, test_start= 420, test_tot= 12, ml_model= 'mdn')
mdn_mon_freq_groups= mdn_mon_freq_df.groupby('reg_indx')
mdn_ann_freq_groups= mdn_ann_freq_df.groupby('reg_indx')

# %% [markdown]
# ### 3.2 Training fire size models

# %%
# %time mdn_gpd_size_model, _= reg_fire_size_func(X_train_dat= X_sizes_train, y_train_dat= y_sizes_train, X_val_dat= X_sizes_val, y_val_dat= y_sizes_val, \
                            size_test_df= fire_size_test, X_test_dat= X_sizes_test, max_size_arr= max_fire_train_arr, sum_size_arr= sum_fire_train_arr, \
                            epochs= 1000, bs= 32, func_flag= 'gpd', lnc_arr= [2, 8, 2], regflag= True, doflag= True, samp_weights= False, loco= True, \
                            rseed= 47) #66
# Out:
# Initialized a MDN with 2 layers and 8 neurons
# 2022-12-29 16:04:45.909152: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# 2022-12-29 16:04:45.912618: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# MDN trained for 396 epochs
# CPU times: user 47.7 s, sys: 5.6 s, total: 53.3 s
# Wall time: 40.9 s

# %%
# %time mdn_gpd_ext_size_model, _= reg_fire_size_func(X_train_dat= X_sizes_train, y_train_dat= y_sizes_train, X_val_dat= X_sizes_val, y_val_dat= y_sizes_val, \
                            size_test_df= fire_size_test, X_test_dat= X_sizes_test, max_size_arr= max_fire_train_arr, sum_size_arr= sum_fire_train_arr, \
                            epochs= 500, bs= 32, func_flag= 'gpd', lnc_arr= [2, 8, 2], regflag= True, doflag= True, samp_weights= True, \
                            samp_weight_arr= samp_weight_arr, loco= True, rseed= 87) #29
# Out:
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 180 epochs
# CPU times: user 23.5 s, sys: 3.07 s, total: 26.6 s
# Wall time: 19.9 s

# %%
mdn_lognorm_ext_size_model, _= reg_fire_size_func(X_train_dat= X_sizes_train, y_train_dat= y_sizes_train, X_val_dat= X_sizes_val, y_val_dat= y_sizes_val, \
                            size_test_df= fire_size_test, X_test_dat= X_sizes_test, max_size_arr= max_fire_train_arr, sum_size_arr= sum_fire_train_arr, \
                            epochs= 500, bs= 32, func_flag= 'lognorm', lnc_arr= [1, 8, 4], regflag= True, doflag= True, samp_weights= True, \
                            samp_weight_arr= samp_weight_arr, loco= True, rseed= 91)

mdn_lognorm_size_model, _= reg_fire_size_func(X_train_dat= X_sizes_train, y_train_dat= y_sizes_train, X_val_dat= X_sizes_val, y_val_dat= y_sizes_val, \
                            size_test_df= fire_size_test, X_test_dat= X_sizes_test, max_size_arr= max_fire_train_arr, sum_size_arr= sum_fire_train_arr, \
                            epochs= 500, bs= 32, func_flag= 'lognorm', lnc_arr= [1, 8, 4], regflag= True, doflag= True, samp_weights= False, loco= True, \
                            rseed= 19)
# Out:
# Initialized a MDN with 1 layers and 8 neurons
# MDN trained for 139 epochs
# Initialized a MDN with 1 layers and 8 neurons
# MDN trained for 330 epochs

# %% [markdown]
# ### 3.3 Predicting regional burned areas

# %%
#largefreqdf= large_freq_scale_fac(fire_size_tot, mdn_mon_freq_df, start_month= 0, final_month= 444)
#largefreqdf.to_hdf('../sav_files/large_fire_freq_scale_fac_df.h5', key= 'df', mode= 'w')
#size_id= '06_24_22'
#mdn_gpd_size_model= tf.keras.models.load_model('../sav_files/fire_size_mods/mdn_gpd_size_model_%s'%size_id, custom_objects= {'gpd_loss': gpd_loss, 'gpd_accuracy': gpd_accuracy})
#mdn_gpd_ext_size_model= tf.keras.models.load_model('../sav_files/fire_size_mods/mdn_gpd_ext_size_model_%s'%size_id, custom_objects= {'gpd_loss': gpd_loss, 'gpd_accuracy': gpd_accuracy})

# %%
#ML fire frequency, observed fire locations

reg_ml_loc_gpd_size_df= grid_size_pred_func(mdn_model= mdn_gpd_size_model, stat_model= gpd_model, max_size_arr= max_fire_train_arr, sum_size_arr= sum_fire_train_arr, \
                                    start_month= 0, final_month= 444, freq_flag= 'ml', loc_flag= 'data', loc_df= freq_loc_df, ml_freq_df= mdn_mon_freq_df, X_freq_test_dat= X_freq_tot, \
                                    debug= False, rescale= True, sf_flag= 'obs_freq_scale_fac', seed= 99) #scaling ML fire freuqency to account for large fire threshold
reg_ml_loc_gpd_size_groups= reg_ml_loc_gpd_size_df.groupby('reg_indx')

reg_ml_loc_gpd_ext_size_df= grid_size_pred_func(mdn_model= mdn_gpd_ext_size_model, stat_model= gpd_model, max_size_arr= max_fire_train_arr, sum_size_arr= sum_fire_train_arr, \
                                    start_month= 0, final_month= 444, freq_flag= 'ml', loc_flag= 'data', loc_df= freq_loc_df, ml_freq_df= mdn_mon_freq_df, X_freq_test_dat= X_freq_tot, \
                                    debug= False, rescale= True, sf_flag= 'obs_freq_scale_fac', seed= 99)
reg_ml_loc_gpd_ext_size_groups= reg_ml_loc_gpd_ext_size_df.groupby('reg_indx')

# %%
#ML fire frequency and locations

reg_ml_fc_gpd_size_df= grid_size_pred_func(mdn_model= mdn_gpd_size_model, stat_model= gpd_model, max_size_arr= max_fire_train_arr, sum_size_arr= sum_fire_train_arr, \
                                    start_month= 0, final_month= 444, freq_flag= 'ml', loc_flag= 'ml', loc_df= freq_loc_df, ml_freq_df= mdn_mon_freq_df, X_freq_test_dat= X_freq_tot, \
                                    debug= False, rescale= True, sf_flag= 'obs_freq_scale_fac', seed= 99)
reg_ml_fc_gpd_size_groups= reg_ml_fc_gpd_size_df.groupby('reg_indx')

reg_ml_fc_gpd_ext_size_df= grid_size_pred_func(mdn_model= mdn_gpd_ext_size_model, stat_model= gpd_model, max_size_arr= max_fire_train_arr, sum_size_arr= sum_fire_train_arr, \
                                    start_month= 0, final_month= 444, freq_flag= 'ml', loc_flag= 'ml', loc_df= freq_loc_df, ml_freq_df= mdn_mon_freq_df, X_freq_test_dat= X_freq_tot, \
                                    debug= False, rescale= True, sf_flag= 'obs_freq_scale_fac', seed= 99)
reg_ml_fc_gpd_ext_size_groups= reg_ml_fc_gpd_ext_size_df.groupby('reg_indx')

# %%
#Observed fire frequency, ML fire locations

reg_ml_freq_gpd_size_df= grid_size_pred_func(mdn_model= mdn_gpd_size_model, stat_model= gpd_model, max_size_arr= max_fire_train_arr, sum_size_arr= sum_fire_train_arr, \
                                    start_month= 0, final_month= 444, freq_flag= 'data', ml_freq_flag= True, ml_freq_df= mdn_mon_freq_df, size_test_df= fire_size_tot, X_size_test_dat= X_sizes_tot, \
                                    debug= False, rescale= True, sf_flag= 'obs_freq_scale_fac', seed= 99)
reg_ml_freq_gpd_size_groups= reg_ml_freq_gpd_size_df.groupby('reg_indx')

reg_ml_freq_gpd_ext_size_df= grid_size_pred_func(mdn_model= mdn_gpd_ext_size_model, stat_model= gpd_model, max_size_arr= max_fire_train_arr, sum_size_arr= sum_fire_train_arr, \
                                    start_month= 0, final_month= 444, freq_flag= 'data', ml_freq_flag= True, ml_freq_df= mdn_mon_freq_df, size_test_df= fire_size_tot, X_size_test_dat= X_sizes_tot, \
                                    debug= False, rescale= True, sf_flag= 'obs_freq_scale_fac', seed= 99)
reg_ml_freq_gpd_ext_size_groups= reg_ml_freq_gpd_ext_size_df.groupby('reg_indx')

# %%
#Observed fire frequency and locations

reg_gpd_ext_data_size_df= grid_size_pred_func(mdn_model= mdn_gpd_ext_size_model, stat_model= gpd_model, max_size_arr= max_fire_train_arr, sum_size_arr= sum_fire_train_arr, \
                        start_month= 0, final_month= 444, freq_flag= 'data', ml_freq_flag= False, size_test_df= fire_size_tot, X_size_test_dat= X_sizes_tot, \
                        debug= False, seed= 13) #lognorm_gpd_model_predict
reg_gpd_ext_data_size_groups= reg_gpd_ext_data_size_df.groupby('reg_indx')

reg_gpd_data_size_df= grid_size_pred_func(mdn_model= mdn_gpd_size_model, stat_model= gpd_model, max_size_arr= max_fire_train_arr, sum_size_arr= sum_fire_train_arr, \
                        start_month= 0, final_month= 444, freq_flag= 'data', ml_freq_flag= False, size_test_df= fire_size_tot, X_size_test_dat= X_sizes_tot, \
                        debug= False, seed= 13) #lognorm_gpd_model_predict
reg_gpd_data_size_groups= reg_gpd_data_size_df.groupby('reg_indx')

# %%
size_id= '08_12_22' #specify size MDN run id
freq_id= '05_30_22' #specify freq MDN run id
ml_flag= False

mdn_gpd_size_model.save('../sav_files/fire_size_mods/mdn_gpd_size_model_%s'%size_id)
mdn_gpd_ext_size_model.save('../sav_files/fire_size_mods/mdn_gpd_ext_size_model_%s'%size_id)
#mdn_lognorm_ext_size_model.save('../sav_files/fire_size_mods/mdn_lognorm_ext_size_model_%s'%size_id)
#mdn_lognorm_size_model.save('../sav_files/fire_size_mods/mdn_lognorm_size_model_%s'%size_id)

if ml_flag:
    reg_ml_freq_gpd_size_df.to_hdf('../sav_files/fire_size_pred_dfs/gpd_mon_fire_size_%s'%size_id + '_ml_freq_data_loc_run_%s'%freq_id + '_df.h5', key= 'df', mode= 'w')
    reg_ml_freq_gpd_ext_size_df.to_hdf('../sav_files/fire_size_pred_dfs/gpd_ext_mon_fire_size_%s'%size_id + '_ml_freq_data_loc_run_%s'%freq_id + '_df.h5', key= 'df', mode= 'w')
    reg_ml_loc_gpd_size_df.to_hdf('../sav_files/fire_size_pred_dfs/gpd_mon_fire_size_%s'%size_id + '_data_freq_ml_loc_run_%s'%freq_id + '_df.h5', key= 'df', mode= 'w')
    reg_ml_loc_gpd_ext_size_df.to_hdf('../sav_files/fire_size_pred_dfs/gpd_ext_mon_fire_size_%s'%size_id + '_data_freq_ml_loc_run_%s'%freq_id + '_df.h5', key= 'df', mode= 'w')
    reg_ml_fc_gpd_size_df.to_hdf('../sav_files/fire_size_pred_dfs/gpd_mon_fire_size_%s'%size_id + '_ml_freq_ml_loc_run_%s'%freq_id + '_df.h5', key= 'df', mode= 'w')
    reg_ml_fc_gpd_ext_size_df.to_hdf('../sav_files/fire_size_pred_dfs/gpd_ext_mon_fire_size_%s'%size_id + '_ml_freq_ml_loc_run_%s'%freq_id + '_df.h5', key= 'df', mode= 'w')
    #reg_ml_lognorm_gpd_size_df.to_hdf('../sav_files/lognorm_gpd_mon_fire_size_%s'%size_id + '_ml_freq_run_%s'%freq_id + '_df.h5', key= 'df', mode= 'w')

reg_gpd_data_size_df.to_hdf('../sav_files/fire_size_pred_dfs/gpd_mon_fire_size_%s'%size_id + '_data_freq_%s_df.h5'%freq_id, key= 'df', mode= 'w')
reg_gpd_ext_data_size_df.to_hdf('../sav_files/fire_size_pred_dfs/gpd_ext_mon_fire_size_%s'%size_id + '_data_freq_%s_df.h5'%freq_id, key= 'df', mode= 'w')
#reg_lognorm_ext_data_size_df.to_hdf('../sav_files/fire_size_pred_dfs/lognorm_ext_mon_fire_size_%s'%size_id + '_data_freq_%s_df.h5'%freq_id, key= 'df', mode= 'w')
#reg_lognorm_data_size_df.to_hdf('../sav_files/fire_size_pred_dfs/lognorm_mon_fire_size_%s'%size_id + '_data_freq_%s_df.h5'%freq_id, key= 'df', mode= 'w')
# Out:
# INFO:tensorflow:Assets written to: ../sav_files/fire_size_mods/mdn_gpd_size_model_08_12_22/assets
# INFO:tensorflow:Assets written to: ../sav_files/fire_size_mods/mdn_gpd_ext_size_model_08_12_22/assets

# %% [markdown]
# #### Plotting

# %%
tot_months= 444

#month_arr= np.linspace(start_month, final_month - 1, tot_months, dtype= np.int64)
month_arr= np.linspace(0, tot_months - 1, tot_months, dtype= np.int64)
year_arr=  np.arange(1984, 2021, 4) #np.asarray([2015, 2016, 2017, 2018, 2019, 2020]) 
yr_arr= np.arange(0, tot_months + 1, 12) 
ind_grid_1= [[1, 2, 6], [7, 8, 9]]
ind_grid_2= [[11, 12, 17], [13, 14, 16]]

reg_name= {1: "Sierra Nevada", 2: "North Coast", 3: "Central Coast", 4: "South Coast", 5: "Pacific NW", 6: "Columbia Plateau", 7:"Northern Rockies", \
          8: "Middle Rockies", 9: "Southern Rockies", 10: "AM Semidesert", 11: "AZ/NM Mts.", 12: "IM Semidesert", 13: "IM Desert", 14: "Northern Great Plains", \
          15: "High Plains", 16: "CO Plateau", 17: "SW Tablelands", 18: "CH Desert"}

# %%
size_id= '03_13_22'
#freq_id= '04_27_22'

reg_data_size_alt_df= pd.read_hdf('../sav_files/fire_size_pred_dfs/gpd_mon_fire_size_%s'%size_id + '_data_freq_df.h5')
reg_data_size_alt_groups= reg_data_size_alt_df.groupby('reg_indx')

# %%
fig, ax= plt.subplots(1, 1, figsize=(18, 4))
regindx= 7

plt.plot(month_arr, mon_burned_area(fire_file, regindx, final_year= 2020), lw= 2, label= 'Observed')
plt.plot(month_arr, reg_gpd_ext_data_size_groups.get_group(regindx)['mean_size'], color= 'orange', lw= 2, label= 'Predicted');
plt.fill_between(month_arr, reg_gpd_ext_data_size_groups.get_group(regindx)['high_1sig_size'], reg_gpd_ext_data_size_groups.get_group(regindx)['low_1sig_size'], \
                                                                                                                             color= 'orange', alpha=0.2)
plt.plot(month_arr[:-12], reg_data_size_alt_groups.get_group(regindx)['mean_size'], color= 'green', lw= 2, alpha= 0.5, label= 'Predicted');
plt.fill_between(month_arr[:-12], reg_data_size_alt_groups.get_group(regindx)['high_1sig_size'], reg_data_size_alt_groups.get_group(regindx)['low_1sig_size'], \
                                                                                                                         color= 'green', alpha=0.2)
#plt.plot(month_arr, reg_ml_gpd_size_groups.get_group(regindx)['mean_size'], color= 'green', lw= 2, label= 'Predicted');
#plt.fill_between(month_arr, reg_ml_gpd_size_groups.get_group(regindx)['high_1sig_size'], reg_ml_gpd_size_groups.get_group(regindx)['low_1sig_size'], \
#                                                                                                                            color= 'green', alpha=0.2)

# %%
# %time perc_arr_jul2017= size_percentile_func(mdn_model= mdn_gpd_ext_size_model, X_sizes_dat= X_sizes_tot, fire_size_df= fire_size_tot, regindx= 1, mindx= 414, rseed= 13)
perc_arr_aug2020= size_percentile_func(mdn_model= mdn_gpd_ext_size_model, X_sizes_dat= X_sizes_tot, fire_size_df= fire_size_tot, regindx= 1, mindx= 439, rseed= 87)
# Out:
# CPU times: user 30.7 s, sys: 790 ms, total: 31.5 s
# Wall time: 35.3 s

# %%
perc_arr_jul2017[0], perc_arr_jul2017[2]
# Out:
# (104.80612, 569.598125)

# %%
perc_arr_aug2020[0], perc_arr_aug2020[2]
# Out:
# (418.7002, 2927.08975)

# %% [markdown]
# ## 4. CV score

# %%
run_id= '07_26_22'
fire_file= "../data/burnarea_12km.nc"
hp_df= ml_fire_size_cv(firefilepath= fire_file, n_iters= 37, lnc_arr= [[2, 8, 2], [1, 16, 2]], func_flag_arr= ['gpd', 'lognorm', 'lognorm_gpd'], \
            mod_type= 'normal', rh_flag= False, add_var_flag= True, add_var_list= ['Delta_T', 'Lightning'], tot_test_months= 12, threshold= 4, scaled= False, \
            tflag= True, run_id= run_id)
hp_df.to_hdf('../sav_files/cv_files/cv_size_res_%s.h5'%run_id, key= 'df', mode= 'w')
# Out:
#   0%|                                                                                                                                                                                                                                                                                                  | 0/37 [00:00<?, ?it/s]
# Initialized a MDN with 2 layers and 8 neurons
# 2022-07-25 22:42:01.061223: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# 2022-07-25 22:42:01.061377: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# MDN trained for 14 epochs
# 2022-07-25 22:42:03.309976: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_2_layers_2_comps_iter_run_1/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 12 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_2_layers_2_comps_iter_run_1/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 15 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_2_layers_2_comps_iter_run_1/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 428 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_1_layers_2_comps_iter_run_1/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 316 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_1_layers_2_comps_iter_run_1/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 566 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_1_layers_2_comps_iter_run_1/assets
#   3%|███████▌                                                                                                                                                                                                                                                                               | 1/37 [07:35<4:33:32, 455.90s/it]
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 226 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_2_layers_2_comps_iter_run_2/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 184 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_2_layers_2_comps_iter_run_2/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 290 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_2_layers_2_comps_iter_run_2/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 609 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_1_layers_2_comps_iter_run_2/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 328 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_1_layers_2_comps_iter_run_2/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 302 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_1_layers_2_comps_iter_run_2/assets
#   5%|███████████████                                                                                                                                                                                                                                                                        | 2/37 [16:33<4:54:04, 504.13s/it]
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 21 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_2_layers_2_comps_iter_run_3/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 10 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_2_layers_2_comps_iter_run_3/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 16 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_2_layers_2_comps_iter_run_3/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 344 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_1_layers_2_comps_iter_run_3/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 325 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_1_layers_2_comps_iter_run_3/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 369 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_1_layers_2_comps_iter_run_3/assets
#   8%|██████████████████████▌                                                                                                                                                                                                                                                                | 3/37 [23:48<4:27:40, 472.37s/it]
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 264 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_2_layers_2_comps_iter_run_4/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 358 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_2_layers_2_comps_iter_run_4/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 361 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_2_layers_2_comps_iter_run_4/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 621 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_1_layers_2_comps_iter_run_4/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 367 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_1_layers_2_comps_iter_run_4/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 530 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_1_layers_2_comps_iter_run_4/assets
#  11%|██████████████████████████████▏                                                                                                                                                                                                                                                        | 4/37 [33:19<4:41:18, 511.48s/it]
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 15 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_2_layers_2_comps_iter_run_5/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 19 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_2_layers_2_comps_iter_run_5/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 188 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_2_layers_2_comps_iter_run_5/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 390 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_1_layers_2_comps_iter_run_5/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 387 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_1_layers_2_comps_iter_run_5/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 411 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_1_layers_2_comps_iter_run_5/assets
#  14%|█████████████████████████████████████▋                                                                                                                                                                                                                                                 | 5/37 [41:17<4:26:16, 499.27s/it]
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 10 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_2_layers_2_comps_iter_run_6/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 10 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_2_layers_2_comps_iter_run_6/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 10 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_2_layers_2_comps_iter_run_6/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 325 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_1_layers_2_comps_iter_run_6/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 12 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_1_layers_2_comps_iter_run_6/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 339 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_1_layers_2_comps_iter_run_6/assets
#  16%|█████████████████████████████████████████████▏                                                                                                                                                                                                                                         | 6/37 [48:30<4:06:15, 476.64s/it]
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 21 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_2_layers_2_comps_iter_run_7/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 39 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_2_layers_2_comps_iter_run_7/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 39 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_2_layers_2_comps_iter_run_7/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 10 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_1_layers_2_comps_iter_run_7/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 10 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_1_layers_2_comps_iter_run_7/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 10 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_1_layers_2_comps_iter_run_7/assets
#  19%|████████████████████████████████████████████████████▊                                                                                                                                                                                                                                  | 7/37 [54:32<3:39:34, 439.14s/it]
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 25 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_2_layers_2_comps_iter_run_8/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 25 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_2_layers_2_comps_iter_run_8/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 429 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_2_layers_2_comps_iter_run_8/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 294 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_1_layers_2_comps_iter_run_8/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 173 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_1_layers_2_comps_iter_run_8/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 177 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_1_layers_2_comps_iter_run_8/assets
#  22%|███████████████████████████████████████████████████████████▉                                                                                                                                                                                                                         | 8/37 [1:01:58<3:33:23, 441.49s/it]
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 34 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_2_layers_2_comps_iter_run_9/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 279 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_2_layers_2_comps_iter_run_9/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 390 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_2_layers_2_comps_iter_run_9/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 249 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_1_layers_2_comps_iter_run_9/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 48 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_1_layers_2_comps_iter_run_9/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 278 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_1_layers_2_comps_iter_run_9/assets
#  24%|███████████████████████████████████████████████████████████████████▍                                                                                                                                                                                                                 | 9/37 [1:09:48<3:30:07, 450.27s/it]
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 206 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_2_layers_2_comps_iter_run_10/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 260 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_2_layers_2_comps_iter_run_10/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 359 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_2_layers_2_comps_iter_run_10/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 295 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_1_layers_2_comps_iter_run_10/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 469 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_1_layers_2_comps_iter_run_10/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 563 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_1_layers_2_comps_iter_run_10/assets
#  27%|██████████████████████████████████████████████████████████████████████████▌                                                                                                                                                                                                         | 10/37 [1:19:13<3:38:37, 485.85s/it]
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 11 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_2_layers_2_comps_iter_run_11/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 439 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_2_layers_2_comps_iter_run_11/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 11 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_2_layers_2_comps_iter_run_11/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 291 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_1_layers_2_comps_iter_run_11/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 333 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_1_layers_2_comps_iter_run_11/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 525 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_1_layers_2_comps_iter_run_11/assets
#  30%|██████████████████████████████████████████████████████████████████████████████████                                                                                                                                                                                                  | 11/37 [1:27:22<3:30:57, 486.82s/it]
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 243 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_2_layers_2_comps_iter_run_12/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 243 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_2_layers_2_comps_iter_run_12/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 521 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_2_layers_2_comps_iter_run_12/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 303 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_1_layers_2_comps_iter_run_12/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 71 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_1_layers_2_comps_iter_run_12/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 544 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_1_layers_2_comps_iter_run_12/assets
#  32%|█████████████████████████████████████████████████████████████████████████████████████████▌                                                                                                                                                                                          | 12/37 [1:36:22<3:29:37, 503.08s/it]
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 422 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_2_layers_2_comps_iter_run_13/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 322 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_2_layers_2_comps_iter_run_13/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 216 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_2_layers_2_comps_iter_run_13/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 561 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_1_layers_2_comps_iter_run_13/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 339 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_1_layers_2_comps_iter_run_13/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 395 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_1_layers_2_comps_iter_run_13/assets
#  35%|████████████████████████████████████████████████████████████████████████████████████████████████▉                                                                                                                                                                                   | 13/37 [1:45:51<3:29:12, 523.03s/it]
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 181 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_2_layers_2_comps_iter_run_14/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 380 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_2_layers_2_comps_iter_run_14/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 460 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_2_layers_2_comps_iter_run_14/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 275 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_1_layers_2_comps_iter_run_14/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 408 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_1_layers_2_comps_iter_run_14/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 639 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_1_layers_2_comps_iter_run_14/assets
#  38%|████████████████████████████████████████████████████████████████████████████████████████████████████████▍                                                                                                                                                                           | 14/37 [1:55:42<3:28:22, 543.58s/it]
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 338 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_2_layers_2_comps_iter_run_15/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 156 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_2_layers_2_comps_iter_run_15/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 600 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_2_layers_2_comps_iter_run_15/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 636 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_1_layers_2_comps_iter_run_15/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 617 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_1_layers_2_comps_iter_run_15/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 576 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_1_layers_2_comps_iter_run_15/assets
#  41%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████▉                                                                                                                                                                    | 15/37 [2:06:26<3:30:18, 573.56s/it]
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 291 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_2_layers_2_comps_iter_run_16/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 335 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_2_layers_2_comps_iter_run_16/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 386 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_2_layers_2_comps_iter_run_16/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 469 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_1_layers_2_comps_iter_run_16/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 330 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_1_layers_2_comps_iter_run_16/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 496 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_1_layers_2_comps_iter_run_16/assets
#  43%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎                                                                                                                                                            | 16/37 [2:15:58<3:20:36, 573.18s/it]
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 89 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_2_layers_2_comps_iter_run_17/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 371 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_2_layers_2_comps_iter_run_17/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 550 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_2_layers_2_comps_iter_run_17/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 281 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_1_layers_2_comps_iter_run_17/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 366 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_1_layers_2_comps_iter_run_17/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 359 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_1_layers_2_comps_iter_run_17/assets
#  46%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊                                                                                                                                                     | 17/37 [2:25:05<3:08:24, 565.22s/it]
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 709 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_2_layers_2_comps_iter_run_18/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 81 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_2_layers_2_comps_iter_run_18/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 290 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_2_layers_2_comps_iter_run_18/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 104 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_1_layers_2_comps_iter_run_18/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 329 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_1_layers_2_comps_iter_run_18/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 678 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_1_layers_2_comps_iter_run_18/assets
#  49%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎                                                                                                                                             | 18/37 [2:34:12<2:57:17, 559.88s/it]
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 14 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_2_layers_2_comps_iter_run_19/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 14 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_2_layers_2_comps_iter_run_19/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 14 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_2_layers_2_comps_iter_run_19/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 437 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_1_layers_2_comps_iter_run_19/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 83 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_1_layers_2_comps_iter_run_19/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 336 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_1_layers_2_comps_iter_run_19/assets
#  51%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋                                                                                                                                      | 19/37 [2:40:53<2:33:37, 512.07s/it]
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 352 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_2_layers_2_comps_iter_run_20/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 298 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_2_layers_2_comps_iter_run_20/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 456 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_2_layers_2_comps_iter_run_20/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 248 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_1_layers_2_comps_iter_run_20/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 202 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_1_layers_2_comps_iter_run_20/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 398 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_1_layers_2_comps_iter_run_20/assets
#  54%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏                                                                                                                              | 20/37 [2:49:52<2:27:24, 520.28s/it]
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 27 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_2_layers_2_comps_iter_run_21/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 335 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_2_layers_2_comps_iter_run_21/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 559 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_2_layers_2_comps_iter_run_21/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 210 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_1_layers_2_comps_iter_run_21/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 544 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_1_layers_2_comps_iter_run_21/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 30 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_1_layers_2_comps_iter_run_21/assets
#  57%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋                                                                                                                       | 21/37 [2:58:19<2:17:42, 516.39s/it]
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 11 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_2_layers_2_comps_iter_run_22/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 13 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_2_layers_2_comps_iter_run_22/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 13 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_2_layers_2_comps_iter_run_22/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 61 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_1_layers_2_comps_iter_run_22/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 298 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_1_layers_2_comps_iter_run_22/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 461 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_1_layers_2_comps_iter_run_22/assets
#  59%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                                                                                                                | 22/37 [3:05:03<2:00:36, 482.42s/it]
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 683 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_2_layers_2_comps_iter_run_23/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 951 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_2_layers_2_comps_iter_run_23/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 301 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_2_layers_2_comps_iter_run_23/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 547 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_1_layers_2_comps_iter_run_23/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 336 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_1_layers_2_comps_iter_run_23/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 375 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_1_layers_2_comps_iter_run_23/assets
#  62%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                                                                                                        | 23/37 [3:16:16<2:05:56, 539.74s/it]
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 22 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_2_layers_2_comps_iter_run_24/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 58 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_2_layers_2_comps_iter_run_24/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 29 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_2_layers_2_comps_iter_run_24/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 308 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_1_layers_2_comps_iter_run_24/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 291 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_1_layers_2_comps_iter_run_24/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 582 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_1_layers_2_comps_iter_run_24/assets
#  65%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                                                                                                 | 24/37 [3:23:47<1:51:12, 513.25s/it]
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 36 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_2_layers_2_comps_iter_run_25/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 346 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_2_layers_2_comps_iter_run_25/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 411 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_2_layers_2_comps_iter_run_25/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 444 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_1_layers_2_comps_iter_run_25/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 484 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_1_layers_2_comps_iter_run_25/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 379 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_1_layers_2_comps_iter_run_25/assets
#  68%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍                                                                                         | 25/37 [3:32:39<1:43:45, 518.82s/it]
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 285 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_2_layers_2_comps_iter_run_26/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 277 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_2_layers_2_comps_iter_run_26/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 270 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_2_layers_2_comps_iter_run_26/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 551 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_1_layers_2_comps_iter_run_26/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 775 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_1_layers_2_comps_iter_run_26/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 352 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_1_layers_2_comps_iter_run_26/assets
#  70%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉                                                                                  | 26/37 [3:42:27<1:38:54, 539.53s/it]
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 205 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_2_layers_2_comps_iter_run_27/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 319 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_2_layers_2_comps_iter_run_27/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 338 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_2_layers_2_comps_iter_run_27/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 207 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_1_layers_2_comps_iter_run_27/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 298 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_1_layers_2_comps_iter_run_27/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 496 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_1_layers_2_comps_iter_run_27/assets
#  73%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍                                                                          | 27/37 [3:51:16<1:29:23, 536.34s/it]
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 306 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_2_layers_2_comps_iter_run_28/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 412 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_2_layers_2_comps_iter_run_28/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 361 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_2_layers_2_comps_iter_run_28/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 40 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_1_layers_2_comps_iter_run_28/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 359 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_1_layers_2_comps_iter_run_28/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 288 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_1_layers_2_comps_iter_run_28/assets
#  76%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊                                                                   | 28/37 [3:59:50<1:19:27, 529.76s/it]
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 258 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_2_layers_2_comps_iter_run_29/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 198 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_2_layers_2_comps_iter_run_29/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 367 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_2_layers_2_comps_iter_run_29/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 323 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_1_layers_2_comps_iter_run_29/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 386 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_1_layers_2_comps_iter_run_29/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 481 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_1_layers_2_comps_iter_run_29/assets
#  78%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎                                                           | 29/37 [4:08:56<1:11:16, 534.52s/it]
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 591 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_2_layers_2_comps_iter_run_30/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 306 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_2_layers_2_comps_iter_run_30/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 272 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_2_layers_2_comps_iter_run_30/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 449 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_1_layers_2_comps_iter_run_30/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 344 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_1_layers_2_comps_iter_run_30/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 535 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_1_layers_2_comps_iter_run_30/assets
#  81%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊                                                    | 30/37 [4:18:56<1:04:37, 553.99s/it]
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 33 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_2_layers_2_comps_iter_run_31/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 432 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_2_layers_2_comps_iter_run_31/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 198 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_2_layers_2_comps_iter_run_31/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 304 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_1_layers_2_comps_iter_run_31/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 511 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_1_layers_2_comps_iter_run_31/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 419 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_1_layers_2_comps_iter_run_31/assets
#  84%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉                                             | 31/37 [4:27:47<54:43, 547.20s/it]
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 21 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_2_layers_2_comps_iter_run_32/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 35 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_2_layers_2_comps_iter_run_32/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 517 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_2_layers_2_comps_iter_run_32/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 30 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_1_layers_2_comps_iter_run_32/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 249 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_1_layers_2_comps_iter_run_32/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 310 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_1_layers_2_comps_iter_run_32/assets
#  86%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍                                     | 32/37 [4:35:23<43:18, 519.76s/it]
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 335 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_2_layers_2_comps_iter_run_33/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 368 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_2_layers_2_comps_iter_run_33/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 266 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_2_layers_2_comps_iter_run_33/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 409 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_1_layers_2_comps_iter_run_33/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 70 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_1_layers_2_comps_iter_run_33/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 250 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_1_layers_2_comps_iter_run_33/assets
#  89%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉                              | 33/37 [4:43:47<34:20, 515.05s/it]
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 24 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_2_layers_2_comps_iter_run_34/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 389 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_2_layers_2_comps_iter_run_34/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 306 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_2_layers_2_comps_iter_run_34/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 499 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_1_layers_2_comps_iter_run_34/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 351 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_1_layers_2_comps_iter_run_34/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 360 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_1_layers_2_comps_iter_run_34/assets
#  92%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍                      | 34/37 [4:52:35<25:57, 519.09s/it]
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 338 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_2_layers_2_comps_iter_run_35/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 392 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_2_layers_2_comps_iter_run_35/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 507 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_2_layers_2_comps_iter_run_35/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 465 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_1_layers_2_comps_iter_run_35/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 28 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_1_layers_2_comps_iter_run_35/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 402 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_1_layers_2_comps_iter_run_35/assets
#  95%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉               | 35/37 [5:01:55<17:42, 531.44s/it]
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 457 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_2_layers_2_comps_iter_run_36/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 373 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_2_layers_2_comps_iter_run_36/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 524 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_2_layers_2_comps_iter_run_36/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 441 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_1_layers_2_comps_iter_run_36/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 378 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_1_layers_2_comps_iter_run_36/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 672 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_1_layers_2_comps_iter_run_36/assets
#  97%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍       | 36/37 [5:12:12<09:16, 556.85s/it]
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 53 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_2_layers_2_comps_iter_run_37/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 358 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_2_layers_2_comps_iter_run_37/assets
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 338 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_2_layers_2_comps_iter_run_37/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 332 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_gpd_1_layers_2_comps_iter_run_37/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 493 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_1_layers_2_comps_iter_run_37/assets
# Initialized a MDN with 1 layers and 16 neurons
# MDN trained for 340 epochs
# INFO:tensorflow:Assets written to: ../sav_files/cv_files/grid_size_runs_07_26_22/mdn_lognorm_gpd_1_layers_2_comps_iter_run_37/assets
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 37/37 [5:21:04<00:00, 520.67s/it]

# %%
run_id= '07_26_22'
hp_df= pd.read_hdf('../sav_files/cv_files/cv_size_res_%s.h5'%run_id, key= 'df', mode= 'w')

# %%
print("GPD Val. Loss: %.2f"%np.mean(hp_df[hp_df['Epochs'] > 30].groupby('n_layers').get_group(2).groupby('func_flag').get_group(func_arr[0])['Val Loss']) + \
      " Val. Accuracy: %.2f"%np.max(hp_df[hp_df['Epochs'] > 30].groupby('n_layers').get_group(2).groupby('func_flag').get_group(func_arr[0])['Val Accuracy']) + \
      " CV score: %.2f"%np.mean(hp_df[hp_df['Epochs'] > 30].groupby('n_layers').get_group(2).groupby('func_flag').get_group(func_arr[0])['Val Accuracy']))
# Out:
# GPD Val. Loss: 4.22 Val. Accuracy: 91.71 CV score: 90.60

# %%
print("Lognorm Val. Loss: %.2f"%np.mean(hp_df[hp_df['Epochs'] > 30].groupby('n_layers').get_group(2).groupby('func_flag').get_group(func_arr[1])['Val Loss']) + \
      " Val. Accuracy: %.2f"%np.max(hp_df[hp_df['Epochs'] > 30].groupby('n_layers').get_group(2).groupby('func_flag').get_group(func_arr[1])['Val Accuracy']) + \
      " CV score: %.2f"%np.mean(hp_df[hp_df['Epochs'] > 30].groupby('n_layers').get_group(2).groupby('func_flag').get_group(func_arr[1])['Val Accuracy']))
# Out:
# Lognorm Val. Loss: 4.45 Val. Accuracy: 91.39 CV score: 86.92

# %%
print("Lognorm-GPD Val. Loss: %.2f"%np.mean(hp_df[hp_df['Epochs'] > 30].groupby('n_layers').get_group(1).groupby('func_flag').get_group(func_arr[2])['Val Loss']) + \
      " Val. Accuracy: %.2f"%np.max(hp_df[hp_df['Epochs'] > 30].groupby('n_layers').get_group(1).groupby('func_flag').get_group(func_arr[2])['Val Accuracy']) + \
      " CV score: %.2f"%np.mean(hp_df[hp_df['Epochs'] > 30].groupby('n_layers').get_group(1).groupby('func_flag').get_group(func_arr[2])['Val Accuracy']))
# Out:
# Lognorm-GPD Val. Loss: 4.36 Val. Accuracy: 87.15 CV score: 85.49

# %% [markdown]
# ## 5. Hyperparameter search

# %%
run_id= '04_16_22'
#fire_file= "../data/burnarea_12km.nc"
#hp_df= ml_fire_size_hyperparam_tuning(firefilepath= fire_file, n_iters= 10, lnc_arr= [[2, 8, 2], [1, 16, 2]], func_flag_arr= ['gpd', 'lognorm', 'lognorm_gpd'], rwt_flag_arr= [False, True], \
#                            dropcols= ['CAPE', 'Solar', 'Ant_Tmax', 'RH', 'Ant_RH', 'FFWI_max3', 'Avgprec_4mo', 'Avgprec_2mo', 'AvgVPD_4mo', 'AvgVPD_2mo', 'Tmax_max7', 'VPD_max7', 'Tmin_max7'], \
#                            start_month= 420, tot_test_months= 12, threshold= 4, scaled= True, run_id= run_id)
#hp_df.to_hdf('../sav_files/grid_size_runs_%s'%run_id + '/grid_size_hyperparams.h5', key= 'df', mode= 'w')

# %%
n_features= 36
start_month= 420
tot_test_months= 12
end_month= start_month + tot_test_months

X_sizes_train, X_sizes_val, y_sizes_train, y_sizes_val, fire_size_train, fire_size_test, X_sizes_test, y_sizes_test, size_scaler= fire_size_data(res= '12km', \
                                                dropcols= ['CAPE', 'Solar', 'Ant_Tmax', 'RH', 'Ant_RH', 'FFWI_max3', 'Avgprec_4mo', 'Avgprec_2mo', \
                                                'AvgVPD_4mo', 'AvgVPD_2mo', 'Tmax_max7', 'VPD_max7', 'Tmin_max7'], start_month= start_month, tot_test_months= tot_test_months, threshold= 4) #size_scaler

X_sizes_train_df= pd.concat([X_sizes_train, X_sizes_val], sort= False).reset_index().drop(columns=['index'])
X_sizes_tot= pd.concat([X_sizes_train_df, X_sizes_test], sort= False).reset_index().drop(columns=['index'])
fire_size_tot= pd.concat([fire_size_train, fire_size_test], sort= False).reset_index().drop(columns=['index'])
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 17847/17847 [00:07<00:00, 2294.64it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 345/345 [00:00<00:00, 1045.79it/s]

# %%
nregions= 18
max_fire_train_arr= []
sum_fire_train_arr= []

for r in tqdm(range(nregions)):
    max_fire_train_arr.append(np.max(np.concatenate([fire_size_train.groupby('reg_indx').get_group(r+1).groupby('fire_month').get_group(k).fire_size.to_numpy()/1e6 \
                                    for k in fire_size_train.groupby('reg_indx').get_group(r+1).groupby('fire_month').groups.keys()])))
    #sum_fire_train_arr.append(np.max([np.sum(fire_size_train.groupby('reg_indx').get_group(r+1).groupby('fire_month').get_group(k).fire_size.to_numpy()/1e6) \
    #                                for k in fire_size_train.groupby('reg_indx').get_group(r+1).groupby('fire_month').groups.keys()]))
    
max_fire_train_arr= np.asarray(max_fire_train_arr)
sum_fire_train_arr= max_fire_size_sum_func(fire_size_df= fire_size_tot) #np.asarray(sum_fire_train_arr)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 18/18 [00:02<00:00,  8.34it/s]

# %%
hp_df['tot_metric']= (0.5*(hp_df['Monthly corr'] + hp_df['Annual corr']))*hp_df['Val Accuracy/Recall']

# %%
hp_df.groupby('func_flag').get_group('gpd').sort_values(by= ['tot_metric'], ascending= False).groupby('rwt_flag').get_group(False).iloc[[3]]
# Out:
#     Iteration  n_layers func_flag  rwt_flag  Val Accuracy/Recall  \
# 12          2         2       gpd     False            83.278398
#
#     Monthly corr  Annual corr  tot_metric
# 12      0.921209     0.904956   76.040069

# %%
hp_df.groupby('func_flag').get_group('gpd').sort_values(by= ['tot_metric'], ascending= False).groupby('rwt_flag').get_group(True).iloc[[0]]
# Out:
#     Iteration  n_layers func_flag  rwt_flag  Val Accuracy/Recall  \
# 85          8         2       gpd      True            62.474836
#
#     Monthly corr  Annual corr  tot_metric
# 85       0.91877     0.889668    56.49093

# %%
run_id= '04_16_22'
f, nl, nc, it= ['gpd', 2, 2, 8]
f_ext, nl_ext, nc_ext, it_ext= ['gpd', 2, 2, 8]
mdn_size_model= tf.keras.models.load_model('../sav_files/grid_size_runs_%s'%run_id + '/mdn_%s_'%f + '%d_layers_'%nl + '%d_comps_'%nc + 'iter_run_%d'%(it), \
                                                                                            custom_objects= {'%s_loss'%f: gpd_loss, '%s_accuracy'%f: gpd_accuracy})
mdn_ext_size_model= tf.keras.models.load_model('../sav_files/grid_size_runs_%s'%run_id + '/mdn_%s_'%f_ext + '%d_layers_'%nl_ext + '%d_comps_'%nc_ext + 'ext_iter_run_%d'%(it_ext), \
                                                                                            custom_objects= {'%s_loss'%f_ext: gpd_loss, '%s_accuracy'%f_ext: gpd_accuracy})

# %%
reg_data_size_df= grid_size_pred_func(mdn_model= mdn_size_model, stat_model= gpd_model, max_size_arr= max_fire_train_arr, sum_size_arr= sum_fire_train_arr, \
                                    start_month= 0, freq_flag= 'data', size_test_df= fire_size_tot, X_size_test_dat= X_sizes_tot, \
                                    debug= False, seed= 99) #lognorm_gpd_model_predict
reg_ext_data_size_df= grid_size_pred_func(mdn_model= mdn_ext_size_model, stat_model= gpd_model, max_size_arr= max_fire_train_arr, sum_size_arr= sum_fire_train_arr, \
                                    start_month= 0, freq_flag= 'data', size_test_df= fire_size_tot, X_size_test_dat= X_sizes_tot, \
                                    debug= False, seed= 99) 

reg_data_size_groups= reg_data_size_df.groupby('reg_indx')
reg_ext_data_size_groups= reg_ext_data_size_df.groupby('reg_indx')

# %%
size_id= '04_16_22'
freq_id= '02_27_22'

reg_data_size_df.to_hdf('../sav_files/grid_size_runs_%s'%run_id + '/gpd_mon_fire_size_%s'%size_id + '_data_freq_df.h5', key= 'df', mode= 'w')
reg_ext_data_size_df.to_hdf('../sav_files/grid_size_runs_%s'%run_id + '/gpd_ext_mon_fire_size_%s'%size_id + '_data_freq_df.h5', key= 'df', mode= 'w')

# %% [markdown]
# ## 6. SHAP analysis

# %%
size_id= '09_12_22'
#mdn_gpd_mod= tf.keras.models.load_model('../sav_files/fire_size_mods/mdn_gpd_size_model_%s'%size_id, custom_objects= {'gpd_loss': gpd_loss, 'gpd_accuracy': gpd_accuracy})
#mdn_gpd_ext_mod= tf.keras.models.load_model('../sav_files/fire_size_mods/mdn_gpd_ext_size_model_%s'%size_id, custom_objects= {'gpd_loss': gpd_loss, 'gpd_accuracy': gpd_accuracy})

tf.random.set_seed(733) #19, 79, 37, 91

es_mon = EarlyStopping(monitor='val_loss', min_delta=0, patience= 10, verbose=0, mode='auto', restore_best_weights=True)
mdn_gpd_mod= MDN_size(layers= 2, neurons= 8, components= 2, initializer= "he_normal", reg= True, regrate= 1e-3, dropout= True)
mdn_gpd_mod.compile(loss= gpd_loss, optimizer= tf.keras.optimizers.Adam(learning_rate= 1e-4), metrics=[gpd_accuracy])
h= mdn_gpd_mod.fit(x= X_sizes_train, y= y_sizes_train, epochs= 500, validation_data=(X_sizes_val, y_sizes_val), callbacks= [es_mon], batch_size= 32, verbose=0)
print("MDN trained for %d epochs"%len(h.history['loss']))
mdn_gpd_mod.save('../sav_files/fire_size_mods/mdn_gpd_size_model_%s'%size_id)

# mdn_gpd_ext_mod= MDN_size(layers= 2, neurons= 8, components= 2, initializer= "he_normal", reg= True, regrate= 1e-3, dropout= True)
# mdn_gpd_ext_mod.compile(loss= gpd_loss, optimizer= tf.keras.optimizers.Adam(learning_rate= 1e-4), metrics=[gpd_accuracy])
# h_ext= mdn_gpd_ext_mod.fit(x= X_sizes_train, y= y_sizes_train, epochs= 500, validation_data=(X_sizes_val, y_sizes_val), callbacks= [es_mon], batch_size= 32, sample_weight= samp_weight_arr, verbose=0)
# print("MDN trained for %d epochs"%len(h_ext.history['loss']))
# mdn_gpd_ext_mod.save('../sav_files/fire_size_mods/mdn_gpd_ext_size_model_%s'%size_id)
# Out:
# MDN trained for 277 epochs

# %%
regarr= range(18) #,  2, 3, 4, 5, 8, 11, 12
X_plot_df= pd.DataFrame([])
tmp_ind_vals= []
reg_shap_vals= []
mean_shap_vals= []

for r in tqdm(regarr): 
    X_bkg_df= X_freq_tot.iloc[fire_freq_tot[fire_freq_tot.fire_freq == 0].groupby('reg_indx').get_group(r+1).index][X_sizes_tot.columns].sample(n= 50, random_state= 13).values
    X_fires_df= X_freq_tot.iloc[fire_freq_tot[(fire_freq_tot.fire_freq == 1)].groupby('reg_indx').get_group(r+1).index][X_sizes_tot.columns] #X_sizes_tot.iloc[fire_size_tot[(fire_size_tot.fire_month >= startmon)&(fire_size_tot.fire_month < finalmon)].groupby('reg_indx').get_group(r).index]
    X_shap_df= pd.concat([X_fires_df, \
            X_freq_tot.iloc[fire_freq_tot[(fire_freq_tot.fire_freq == 0)].groupby('reg_indx').get_group(r+1).index][X_sizes_tot.columns].sample(n= int(len(X_fires_df)/3), random_state= 13)]).sample(frac= 1.0)
    X_plot_df= X_plot_df.append(pd.concat([X_shap_df.reset_index().drop(columns= ['index']), pd.DataFrame({'reg_indx': (r+1)*np.ones(len(X_shap_df), dtype= int)})], axis= 1), ignore_index= True)
    
    def f(X):
        reg_gpd_size_df= grid_size_pred_func(mdn_model= mdn_gpd_mod, stat_model= gpd_model, max_size_arr= max_fire_train_arr, sum_size_arr= sum_fire_train_arr, \
                        X_size_test_dat= X, shap_flag= True, regindx= r, seed= 13)
    
        return reg_gpd_size_df['mean_size']
    
    explainer= shap.KernelExplainer(f, X_bkg_df) #df_train_normed_summary.data #df_train_normed_summary= shap.kmeans(X_freq_tot.iloc[fire_freq_tot[fire_freq_tot.fire_freq == 0].groupby('reg_indx').get_group(r).index][X_sizes_tot.columns].values, 50)
    shap_values= explainer.shap_values(X_shap_df.values, nsamples= 500)
    tmp_ind_vals.append(np.argsort(np.mean(abs(shap_values), axis= 0)))
    reg_shap_vals.append(shap_values)
    mean_shap_vals.append(np.sort(np.mean(abs(shap_values), axis= 0)))

X_plot_df.to_hdf('../sav_files/shap_files/fire_size_data_%s.h5'%size_id, key= 'df', mode= 'w')
pd.DataFrame(np.vstack(reg_shap_vals), columns= X_sizes_test.columns).to_hdf('../sav_files/shap_files/fire_size_shap_%s.h5'%size_id, key= 'df', mode= 'w')
# Out:
#   0%|                                                    | 0/18 [00:00<?, ?it/s]
#   0%|          | 0/1040 [00:00<?, ?it/s]
#   6%|██▎                                      | 1/18 [16:24<4:39:00, 984.76s/it]
#   0%|          | 0/457 [00:00<?, ?it/s]
#  11%|████▌                                    | 2/18 [23:51<2:58:14, 668.41s/it]
#   0%|          | 0/1088 [00:00<?, ?it/s]
#  17%|██████▊                                  | 3/18 [41:22<3:30:46, 843.08s/it]
#   0%|          | 0/616 [00:00<?, ?it/s]
#  22%|█████████                                | 4/18 [51:14<2:53:32, 743.77s/it]
#   0%|          | 0/762 [00:00<?, ?it/s]
#  28%|██████████▊                            | 5/18 [1:03:23<2:40:03, 738.71s/it]
#   0%|          | 0/1060 [00:00<?, ?it/s]
#  33%|█████████████                          | 6/18 [1:20:02<2:45:26, 827.21s/it]
#   0%|          | 0/552 [00:00<?, ?it/s]
#  39%|███████████████▏                       | 7/18 [1:28:41<2:13:10, 726.45s/it]
#   0%|          | 0/2354 [00:00<?, ?it/s]
#  44%|████████████████▉                     | 8/18 [2:05:38<3:20:09, 1200.92s/it]
#   0%|          | 0/692 [00:00<?, ?it/s]
#  50%|███████████████████                   | 9/18 [2:16:48<2:35:15, 1035.02s/it]
#   0%|          | 0/886 [00:00<?, ?it/s]
#  56%|█████████████████████                 | 10/18 [2:31:02<2:10:31, 978.88s/it]
#   0%|          | 0/1756 [00:00<?, ?it/s]
#  61%|██████████████████████▌              | 11/18 [2:58:49<2:18:47, 1189.62s/it]
#   0%|          | 0/3778 [00:00<?, ?it/s]
#  67%|████████████████████████▋            | 12/18 [3:58:17<3:11:19, 1913.21s/it]
#   0%|          | 0/2944 [00:00<?, ?it/s]
#  72%|██████████████████████████▋          | 13/18 [4:44:39<3:01:20, 2176.20s/it]
#   0%|          | 0/1485 [00:00<?, ?it/s]
#  78%|████████████████████████████▊        | 14/18 [5:08:15<2:09:46, 1946.58s/it]
#   0%|          | 0/368 [00:00<?, ?it/s]
#  83%|██████████████████████████████▊      | 15/18 [5:14:29<1:13:38, 1472.71s/it]
#   0%|          | 0/1020 [00:00<?, ?it/s]
#  89%|██████████████████████████████████▋    | 16/18 [5:30:44<44:05, 1322.96s/it]
#   0%|          | 0/456 [00:00<?, ?it/s]
#  94%|████████████████████████████████████▊  | 17/18 [5:38:09<17:38, 1058.95s/it]
#   0%|          | 0/396 [00:00<?, ?it/s]
# 100%|███████████████████████████████████████| 18/18 [5:42:46<00:00, 1142.57s/it]

# %%
regindx= 6
#shap.summary_plot(reg_shap_vals[2], X_plot_df.groupby('reg_indx').get_group(regindx).drop(columns= ['reg_indx']))
shap.summary_plot(reg_shap_vals[regindx-1], X_plot_df.groupby('reg_indx').get_group(regindx).drop(columns= ['reg_indx']))

# %%
regindx= 6
shap.dependence_plot(0, reg_shap_vals[regindx-1],  X_plot_df.groupby('reg_indx').get_group(regindx).drop(columns= ['reg_indx']))

# %%
forest_reg_arr= np.array([0, 1, 2, 3, 4, 6, 7, 8, 10])

# %%
shap.summary_plot(np.vstack(np.array(reg_shap_vals)[forest_reg_arr]), pd.DataFrame(np.vstack([X_plot_df.groupby('reg_indx').get_group(k).drop(columns= ['reg_indx']) for k in (1+forest_reg_arr)]), columns= X_sizes_test.columns))

# %%
shap.dependence_plot(1, np.vstack(np.array(reg_shap_vals)[forest_reg_arr]), pd.DataFrame(np.vstack([X_plot_df.groupby('reg_indx').get_group(k).drop(columns= ['reg_indx']) \
                                                        for k in (1+forest_reg_arr)]), columns= X_sizes_test.columns), interaction_index= 'Tmax', show= False)
#plt.savefig('../paper_plots/shap_size_dep_forests.jpg', bbox_inches='tight', dpi= 300);

# %% [markdown]
# ## 7. Fire size LOCO analysis

# %%
run_id= '22_01_28'
var_df= fire_size_loco(firefile= fire_file, reg_freq_df= reg_freq_df, res= '12km', n_iters= 50, n_epochs= 500, bs= 32, run_id= run_id)
var_df.to_hdf('../sav_files/loco_size_runs_%s/'%run_id + 'variables_size_loco_runs_%s.h5'%run_id, key= 'df', mode= 'w')
# Out:
#   0%|                                                    | 0/50 [00:00<?, ?it/s]2022-01-28 14:42:44.756682: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# 2022-01-28 14:42:44.756846: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 244 epochs
# 2022-01-28 14:43:28.395607: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: ../sav_files/loco_size_runs_22_01_28/mdn_12km_gpd_iter_run_1_var_0/assets
# Loading predictor variable data without VPD
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 274 epochs
# INFO:tensorflow:Assets written to: ../sav_files/loco_size_runs_22_01_28/mdn_12km_gpd_iter_run_1_var_1/assets
# Loading predictor variable data without Tmax
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 289 epochs
# INFO:tensorflow:Assets written to: ../sav_files/loco_size_runs_22_01_28/mdn_12km_gpd_iter_run_1_var_2/assets
# Loading predictor variable data without Forest
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 329 epochs
# INFO:tensorflow:Assets written to: ../sav_files/loco_size_runs_22_01_28/mdn_12km_gpd_iter_run_1_var_3/assets
# Loading predictor variable data without Urban
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 276 epochs
# INFO:tensorflow:Assets written to: ../sav_files/loco_size_runs_22_01_28/mdn_12km_gpd_iter_run_1_var_4/assets
# Loading predictor variable data without FM1000
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 276 epochs
# INFO:tensorflow:Assets written to: ../sav_files/loco_size_runs_22_01_28/mdn_12km_gpd_iter_run_1_var_5/assets
# Loading predictor variable data without Prec
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 291 epochs
# INFO:tensorflow:Assets written to: ../sav_files/loco_size_runs_22_01_28/mdn_12km_gpd_iter_run_1_var_6/assets
# Loading predictor variable data without Antprec
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 291 epochs
# INFO:tensorflow:Assets written to: ../sav_files/loco_size_runs_22_01_28/mdn_12km_gpd_iter_run_1_var_7/assets
# Loading predictor variable data without Ant_VPD
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 276 epochs
# INFO:tensorflow:Assets written to: ../sav_files/loco_size_runs_22_01_28/mdn_12km_gpd_iter_run_1_var_8/assets
# Loading predictor variable data without Avgprec
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 244 epochs
# INFO:tensorflow:Assets written to: ../sav_files/loco_size_runs_22_01_28/mdn_12km_gpd_iter_run_1_var_9/assets
# Loading predictor variable data without FFWI
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 200 epochs
# INFO:tensorflow:Assets written to: ../sav_files/loco_size_runs_22_01_28/mdn_12km_gpd_iter_run_1_var_10/assets
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
#   2%|▊                                       | 1/50 [14:41<11:59:54, 881.51s/it]
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 273 epochs
# INFO:tensorflow:Assets written to: ../sav_files/loco_size_runs_22_01_28/mdn_12km_gpd_iter_run_2_var_0/assets
# Loading predictor variable data without VPD
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 252 epochs
# INFO:tensorflow:Assets written to: ../sav_files/loco_size_runs_22_01_28/mdn_12km_gpd_iter_run_2_var_1/assets
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Loading predictor variable data without Tmax
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 236 epochs
# INFO:tensorflow:Assets written to: ../sav_files/loco_size_runs_22_01_28/mdn_12km_gpd_iter_run_2_var_2/assets
# Loading predictor variable data without Forest
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 170 epochs
# INFO:tensorflow:Assets written to: ../sav_files/loco_size_runs_22_01_28/mdn_12km_gpd_iter_run_2_var_3/assets
# Loading predictor variable data without Urban
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 291 epochs
# INFO:tensorflow:Assets written to: ../sav_files/loco_size_runs_22_01_28/mdn_12km_gpd_iter_run_2_var_4/assets
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Loading predictor variable data without FM1000
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 12 epochs
# INFO:tensorflow:Assets written to: ../sav_files/loco_size_runs_22_01_28/mdn_12km_gpd_iter_run_2_var_5/assets
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Loading predictor variable data without Prec
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 236 epochs
# INFO:tensorflow:Assets written to: ../sav_files/loco_size_runs_22_01_28/mdn_12km_gpd_iter_run_2_var_6/assets
# Loading predictor variable data without Antprec
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 170 epochs
# INFO:tensorflow:Assets written to: ../sav_files/loco_size_runs_22_01_28/mdn_12km_gpd_iter_run_2_var_7/assets
# Loading predictor variable data without Ant_VPD
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 10 epochs
# INFO:tensorflow:Assets written to: ../sav_files/loco_size_runs_22_01_28/mdn_12km_gpd_iter_run_2_var_8/assets
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Loading predictor variable data without Avgprec
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 225 epochs
# INFO:tensorflow:Assets written to: ../sav_files/loco_size_runs_22_01_28/mdn_12km_gpd_iter_run_2_var_9/assets
# Loading predictor variable data without FFWI
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 337 epochs
# INFO:tensorflow:Assets written to: ../sav_files/loco_size_runs_22_01_28/mdn_12km_gpd_iter_run_2_var_10/assets
#   4%|█▌                                      | 2/50 [26:58<10:37:22, 796.71s/it]
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 215 epochs
# INFO:tensorflow:Assets written to: ../sav_files/loco_size_runs_22_01_28/mdn_12km_gpd_iter_run_3_var_0/assets
# Loading predictor variable data without VPD
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 261 epochs
# INFO:tensorflow:Assets written to: ../sav_files/loco_size_runs_22_01_28/mdn_12km_gpd_iter_run_3_var_1/assets
# Loading predictor variable data without Tmax
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 261 epochs
# INFO:tensorflow:Assets written to: ../sav_files/loco_size_runs_22_01_28/mdn_12km_gpd_iter_run_3_var_2/assets
# Loading predictor variable data without Forest
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 333 epochs
# INFO:tensorflow:Assets written to: ../sav_files/loco_size_runs_22_01_28/mdn_12km_gpd_iter_run_3_var_3/assets
# Loading predictor variable data without Urban
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 369 epochs
# INFO:tensorflow:Assets written to: ../sav_files/loco_size_runs_22_01_28/mdn_12km_gpd_iter_run_3_var_4/assets
# Loading predictor variable data without FM1000
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 212 epochs
# INFO:tensorflow:Assets written to: ../sav_files/loco_size_runs_22_01_28/mdn_12km_gpd_iter_run_3_var_5/assets
# Loading predictor variable data without Prec
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 218 epochs
# INFO:tensorflow:Assets written to: ../sav_files/loco_size_runs_22_01_28/mdn_12km_gpd_iter_run_3_var_6/assets
# Loading predictor variable data without Antprec
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 333 epochs
# INFO:tensorflow:Assets written to: ../sav_files/loco_size_runs_22_01_28/mdn_12km_gpd_iter_run_3_var_7/assets
# Loading predictor variable data without Ant_VPD
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 213 epochs
# INFO:tensorflow:Assets written to: ../sav_files/loco_size_runs_22_01_28/mdn_12km_gpd_iter_run_3_var_8/assets
# Loading predictor variable data without Avgprec
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 369 epochs
# INFO:tensorflow:Assets written to: ../sav_files/loco_size_runs_22_01_28/mdn_12km_gpd_iter_run_3_var_9/assets
# Loading predictor variable data without FFWI
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 215 epochs
# INFO:tensorflow:Assets written to: ../sav_files/loco_size_runs_22_01_28/mdn_12km_gpd_iter_run_3_var_10/assets
#   6%|██▍                                     | 3/50 [41:36<10:52:59, 833.60s/it]
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 395 epochs
# INFO:tensorflow:Assets written to: ../sav_files/loco_size_runs_22_01_28/mdn_12km_gpd_iter_run_4_var_0/assets
# Loading predictor variable data without VPD
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 296 epochs
# INFO:tensorflow:Assets written to: ../sav_files/loco_size_runs_22_01_28/mdn_12km_gpd_iter_run_4_var_1/assets
# Loading predictor variable data without Tmax
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 322 epochs
# INFO:tensorflow:Assets written to: ../sav_files/loco_size_runs_22_01_28/mdn_12km_gpd_iter_run_4_var_2/assets
# Loading predictor variable data without Forest
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 296 epochs
# INFO:tensorflow:Assets written to: ../sav_files/loco_size_runs_22_01_28/mdn_12km_gpd_iter_run_4_var_3/assets
# Loading predictor variable data without Urban
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 348 epochs
# INFO:tensorflow:Assets written to: ../sav_files/loco_size_runs_22_01_28/mdn_12km_gpd_iter_run_4_var_4/assets
# Loading predictor variable data without FM1000
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 329 epochs
# INFO:tensorflow:Assets written to: ../sav_files/loco_size_runs_22_01_28/mdn_12km_gpd_iter_run_4_var_5/assets
# Loading predictor variable data without Prec
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 296 epochs
# INFO:tensorflow:Assets written to: ../sav_files/loco_size_runs_22_01_28/mdn_12km_gpd_iter_run_4_var_6/assets
# Loading predictor variable data without Antprec
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 275 epochs
# INFO:tensorflow:Assets written to: ../sav_files/loco_size_runs_22_01_28/mdn_12km_gpd_iter_run_4_var_7/assets
# Loading predictor variable data without Ant_VPD
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 427 epochs
# INFO:tensorflow:Assets written to: ../sav_files/loco_size_runs_22_01_28/mdn_12km_gpd_iter_run_4_var_8/assets
# Loading predictor variable data without Avgprec
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 374 epochs
# INFO:tensorflow:Assets written to: ../sav_files/loco_size_runs_22_01_28/mdn_12km_gpd_iter_run_4_var_9/assets
# Loading predictor variable data without FFWI
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 351 epochs
# INFO:tensorflow:Assets written to: ../sav_files/loco_size_runs_22_01_28/mdn_12km_gpd_iter_run_4_var_10/assets
#   8%|███▏                                    | 4/50 [58:46<11:38:40, 911.32s/it]
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 13 epochs
# INFO:tensorflow:Assets written to: ../sav_files/loco_size_runs_22_01_28/mdn_12km_gpd_iter_run_5_var_0/assets
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Loading predictor variable data without VPD
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 10 epochs
# INFO:tensorflow:Assets written to: ../sav_files/loco_size_runs_22_01_28/mdn_12km_gpd_iter_run_5_var_1/assets
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Loading predictor variable data without Tmax
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 10 epochs
# INFO:tensorflow:Assets written to: ../sav_files/loco_size_runs_22_01_28/mdn_12km_gpd_iter_run_5_var_2/assets
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Loading predictor variable data without Forest
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 10 epochs
# INFO:tensorflow:Assets written to: ../sav_files/loco_size_runs_22_01_28/mdn_12km_gpd_iter_run_5_var_3/assets
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# ...
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Loading predictor variable data without Antprec
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 14 epochs
# INFO:tensorflow:Assets written to: ../sav_files/loco_size_runs_22_01_28/mdn_12km_gpd_iter_run_50_var_7/assets
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Loading predictor variable data without Ant_VPD
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 14 epochs
# INFO:tensorflow:Assets written to: ../sav_files/loco_size_runs_22_01_28/mdn_12km_gpd_iter_run_50_var_8/assets
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Loading predictor variable data without Avgprec
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 252 epochs
# INFO:tensorflow:Assets written to: ../sav_files/loco_size_runs_22_01_28/mdn_12km_gpd_iter_run_50_var_9/assets
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /Users/hyfives-lamont/miniforge3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Loading predictor variable data without FFWI
# Initialized a MDN with 2 layers and 8 neurons
# MDN trained for 500 epochs
# INFO:tensorflow:Assets written to: ../sav_files/loco_size_runs_22_01_28/mdn_12km_gpd_iter_run_50_var_10/assets
# 100%|███████████████████████████████████████| 50/50 [11:09:08<00:00, 802.97s/it]

# %%
n_regions= 18
reg_name= {1: "Sierra Nevada", 2: "North Coast", 3: "Central Coast", 4: "South Coast", 5: "Pacific NW", 6: "Columbia Plateau", 7:"Northern Rockies", \
          8: "Middle Rockies", 9: "Southern Rockies", 10: "AM Semidesert", 11: "AZ/NM Mts.", 12: "IM Semidesert", 13: "IM Desert", 14: "Northern Great Plains", 15: "High Plains", 16: "CO Plateau", 17: "SW Tablelands", 18: "CH Desert"}
varlist= np.array(['All', 'VPD', 'Tmax', 'Forest', 'Urban', 'FM1000'])

# %%
run_id= '22_01_27'
var_df= pd.read_hdf('../sav_files/loco_size_runs_%s'%run_id + '/variables_size_loco_runs_%s.h5'%run_id)

# %%
reg_loss_arr= []
reg_argind= [] #.sort_values(by= ["Loss"], ascending= False).iloc[[0]]
for r in tqdm(range(n_regions)):
    reg_loss= np.asarray([var_df.groupby('reg_indx').get_group(r+1).groupby('Variable').get_group(v).sort_values(by= ["Loss"]).iloc[[0]]['Loss'] \
                                                                for v in range(len(varlist))]).flatten()
    reg_argind.append(np.argsort(abs(reg_loss - reg_loss[0])/reg_loss[0])[1:])
    reg_loss_arr.append(np.sort(abs(reg_loss - reg_loss[0])/reg_loss[0])[1:])
# Out:
# 100%|██████████████████████████████████████████| 18/18 [00:00<00:00, 138.29it/s]

# %%
var_df.groupby('Iteration').get_group(28).groupby('reg_indx').get_group(8).sort_values(by=["Loss"], ascending= False).dropna()
# Out:
#       Iteration  Variable  reg_indx  Pearson_r  Emp_Accuracy  Mod_Accuracy  \
# 2977         28         3         8   0.613147     97.217179     54.310120
# 2923         28         0         8   0.526209     97.296789     57.432701
# 3013         28         5         8   0.554400     97.341993     61.836975
# 2995         28         4         8   0.490348     97.452610     60.475075
# 2959         28         2         8   0.592903     97.459154     59.876366
# 2941         28         1         8   0.612683     97.575334     59.973370
#
#           Loss
# 2977  4.545679
# 2923  4.433491
# 3013  4.348647
# 2995  4.318840
# 2959  4.280407
# 2941  4.244106

# %%
var_df.groupby('reg_indx').get_group(1).groupby('Iteration').get_group(8).sort_values(by= ["Loss"], ascending= False)
# Out:
#      Iteration  Variable  reg_indx  Pearson_r  Emp_Accuracy  Mod_Accuracy  \
# 774          8         1         1   0.648784     97.322220     72.639618
# 792          8         2         1   0.560872     97.464638     75.771088
# 810          8         3         1   0.626891     97.598151     77.390388
# 756          8         0         1   0.519324     97.537460     80.048119
# 828          8         4         1   0.573483     97.519024     79.605652
# 846          8         5         1   0.647946     97.640383     77.503227
#
#          Loss
# 774  4.148787
# 792  4.025559
# 810  3.940776
# 756  3.936488
# 828  3.928916
# 846  3.877088

# %%
np.asarray([var_df.groupby('reg_indx').get_group(8).groupby('Variable').get_group(v).sort_values(by= ["Emp_Accuracy"], ascending= False).iloc[[0]]['Emp_Accuracy'] \
                                                                for v in range(len(varlist))]).flatten()
# Out:
# array([97.58167839, 97.59054995, 97.59447384, 97.6452167 , 97.65708256,
#        97.65451574])

# %%
loco_grid= [[[1, 2], [3, 4]], [[5, 9], [8, 12]]] 

fig, ax= plt.subplots(2, 2, figsize=(14, 10))
#plt.suptitle(r'Monthly fire frequency across regions', fontsize= 18);
#fig.text(0.04, 0.5, r'', va='center', rotation='vertical', fontsize= 16);
fig.text(0.5, 0.04, r'LOCO feature importance', ha='center', fontsize= 16)

for i in range(2):
    for j in range(2):
        regindx= loco_grid[1][i][j]
        
        ax[i, j].barh(varlist[reg_argind[regindx - 1]], reg_loss_arr[regindx - 1]);
        ax[i, j].set_title(reg_name[regindx], fontsize= 14);
            
        fig.subplots_adjust(hspace= 0.4, wspace= 0.3)
        #fig.minorticks_on()
        ax[i, j].tick_params(labeltop=False, top=True, labelright=False, right=True, which='both', labelsize= 12);
        ax[i, j].grid(b=True, which='major', color='black', alpha=0.05, linestyle='-');
        ax[i, j].grid(b=True, which='minor', color='black', alpha=0.01, linestyle='-');
#plt.savefig('../plots/loco_fire_size_1.pdf', bbox_inches='tight');

# %%
tot_avg_loss= np.asarray([np.mean([var_df.groupby('reg_indx').get_group(r+1).groupby('Variable').get_group(v).sort_values(by= ["Loss"]).iloc[[0]]['Loss'] \
                                                                   for r in range(n_regions)]) for v in range(len(varlist))])
tot_argind= np.argsort(abs(tot_avg_loss - tot_avg_loss[0]))

# %%
fig, ax= plt.subplots(1, 1, figsize=(7, 5))
ax.barh(varlist[tot_argind][1:], np.sort(abs(tot_avg_loss - tot_avg_loss[0])/tot_avg_loss[0])[1:]);
ax.set_title(r'Western United States', fontsize= 14);
ax.set_xlabel(r'LOCO feature importance', ha='center', fontsize= 14, labelpad= 10)
fig.subplots_adjust(hspace= 0.4, wspace= 0.3)
#fig.minorticks_on()
ax.tick_params(labeltop=False, top=True, labelright=False, right=True, which='both', labelsize= 12);
ax.grid(b=True, which='major', color='black', alpha=0.05, linestyle='-');
ax.grid(b=True, which='minor', color='black', alpha=0.01, linestyle='-');
#plt.savefig('../plots/loco_fire_size_all.pdf', bbox_inches='tight');

# %% [markdown]
# ## Sanity Check

# %%
fire_size_tot.groupby('reg_indx').get_group(1).groupby('fire_month').get_group(414)[['fire_size', 'Tmax', 'Prec', 'FM1000', 'VPD', 'VPD_max3', 'Wind', 'Road_dist', 'AvgVPD_2mo', 'Avgprec_2mo', 'Forest']]
# Out:
#         fire_size       Tmax       Prec    FM1000        VPD   VPD_max3  \
# 3126  148098600.0  33.951298  13.542495  7.763168  23.572466  25.285120
# 3133   11151900.0  25.789321   6.959935  7.870200  14.939244  27.627552
# 3137    7940700.0  26.670000   2.500000  9.450000  17.379999  22.940001
# 3138  339348600.0  33.873716   0.991756  7.608802  25.508645  37.772919
#
#           Wind  Road_dist  AvgVPD_2mo  Avgprec_2mo    Forest
# 3126  5.687621   4.139725   11.898043    24.347814  0.261242
# 3133  8.949650  14.542511    9.754461     2.560123  0.025074
# 3137  5.680000   8.281000    6.630001    53.090000  0.470771
# 3138  3.639306   4.687667   13.448013     3.193128  0.694257

# %%
fire_size_tot.groupby('reg_indx').get_group(1).groupby('fire_month').get_group(439)[['fire_size', 'Tmax', 'Prec', 'FM1000', 'VPD', 'VPD_max3', 'Wind', 'Road_dist', 'AvgVPD_2mo', 'Avgprec_2mo', 'Forest']]
# Out:
#         fire_size       Tmax       Prec    FM1000        VPD   VPD_max3  \
# 229  3.136570e+07  34.117635   0.195977  5.686026  26.346385  30.462580
# 230  8.325600e+06  25.802678   3.806636  6.359216  15.965162  19.793004
# 233  1.890729e+08  29.580038   4.189499  7.036686  18.763730  22.275541
# 242  3.408600e+07  24.167081   0.000000  5.593073  13.053317  14.027283
# 243  1.195488e+08  29.682608   2.077581  6.746216  19.220279  21.482797
# 244  1.290045e+09  32.988653   1.340518  5.988334  22.773767  35.526473
# 254  6.905879e+08  28.725209   0.006381  5.644728  16.591170  21.962175
# 256  5.325800e+06  22.102562   0.006550  6.582792  11.078645  13.277080
# 257  1.082603e+08  23.641312  14.203387  7.887149  13.341307  17.094066
#
#          Wind  Road_dist  AvgVPD_2mo  Avgprec_2mo    Forest
# 229  5.867426  12.971283   22.592053     3.581438  0.208365
# 230  3.804542   2.699168   12.337156    12.440183  0.726575
# 233  4.720535  12.197800   14.763996    14.024440  0.230561
# 242  5.956480  32.555500    9.720584     1.095384  0.323434
# 243  4.702990  11.905957   14.932389     7.782247  0.487945
# 244  3.517662  17.636138   18.645041     1.601382  0.772891
# 254  4.076484  38.306195   13.334143     0.437863  0.599064
# 256  5.770608  18.817928    8.592443     1.734247  0.308717
# 257  5.154809  13.409751   11.183266    19.238826  0.390118

# %%
plt.hist(fire_size_tot[fire_size_tot['fire_month'] == 54].groupby('reg_indx').get_group(8)['fire_size'])
plt.hist(fire_size_tot[fire_size_tot['fire_month'] == 379].groupby('reg_indx').get_group(8)['fire_size'])
# Out:
# (array([23.,  3.,  2.,  1.,  1.,  2.,  1.,  2.,  0.,  1.]),
#  array([4.0212000e+06, 3.9286980e+07, 7.4552760e+07, 1.0981854e+08,
#         1.4508432e+08, 1.8035010e+08, 2.1561588e+08, 2.5088166e+08,
#         2.8614744e+08, 3.2141322e+08, 3.5667900e+08]),
#  <BarContainer object of 10 artists>)

# %%
kde_density_1= stats.gaussian_kde(fire_size_arr, bw_method= "silverman")
kde_density_2= stats.gaussian_kde(fire_size_arr, bw_method= "scott")
kde_density_3= stats.gaussian_kde(fire_size_arr, bw_method= 0.3)

plt.plot(np.sort(y_sizes_train), 10**-6/kde_density_1.evaluate(np.sort(y_sizes_train)))
plt.plot(np.sort(y_sizes_train), 10**-6/kde_density_2.evaluate(np.sort(y_sizes_train)))
plt.plot(np.sort(y_sizes_train), 10**-6/kde_density_3.evaluate(np.sort(y_sizes_train)))
plt.plot(np.sort(y_sizes_train), empcdf_sizes.cdf(np.sort(y_sizes_train)).numpy())
plt.yscale('log')

# %%
#plt.plot(np.sort(s), (1 - np.sort(cdf_emp_sizes)))
plt.plot(np.sort(y_sizes_train), (1/0.73)*kde_density.evaluate(np.sort(y_sizes_train)))
plt.plot(np.sort(fire_size_arr), (1/4)*sampling_func(y_sizes_train)(np.sort(fire_size_arr)))

plt.yscale('log')

# %%
# %time mdn_lognorm_gpd_size_model, _= reg_fire_size_func(X_train_dat= X_sizes_train, y_train_dat= y_sizes_train, X_val_dat= X_sizes_val, y_val_dat= y_sizes_val, \
#                             size_test_df= fire_size_test, X_test_dat= X_sizes_test, max_size_arr= max_fire_train_arr, sum_size_arr= sum_fire_train_arr, \
#                             epochs= 500, bs= 32, func_flag= 'lognorm_gpd', lnc_arr= [2, 8, 2], samp_weights= True, samp_weight_arr= samp_weight_arr, loco= True, rseed= 87)

# reg_lognorm_gpd_data_size_df= grid_size_pred_func(mdn_model= mdn_lognorm_gpd_size_model, stat_model= lognorm_gpd_model_predict, max_size_arr= max_fire_train_arr, sum_size_arr= sum_fire_train_arr, \
#                                     start_month= 0, freq_flag= 'data', size_test_df= fire_size_tot, X_size_test_dat= X_sizes_tot, \
#                                     debug= False, seed= 99) #lognorm_gpd_model_predict
# reg_lognorm_gpd_data_size_groups= reg_lognorm_gpd_data_size_df.groupby('reg_indx')

# reg_ml_gpd_size_df= grid_size_pred_func(mdn_model= mdn_gpd_size_model, stat_model= gpd_model, max_size_arr= max_fire_train_arr, sum_size_arr= sum_fire_train_arr, \
#                                     start_month= 0, freq_flag= 'ml', loc_df= freq_loc_df, ml_freq_df= mdn_mon_freq_df, X_freq_test_dat= X_test_tot, \
#                                     debug= False, seed= 99)
# reg_ml_gpd_size_groups= reg_ml_gpd_size_df.groupby('reg_indx')

# %%
# reg_lognorm_ext_data_size_df= grid_size_pred_func(mdn_model= mdn_lognorm_ext_size_model, stat_model= lognorm_model, max_size_arr= max_fire_train_arr, sum_size_arr= sum_fire_train_arr, \
#                         start_month= 0, final_month= 444, freq_flag= 'data', ml_freq_flag= False, size_test_df= fire_size_tot, X_size_test_dat= X_sizes_tot, \
#                         debug= False, seed= 13) #lognorm_gpd_model_predict
# reg_lognorm_ext_data_size_groups= reg_lognorm_ext_data_size_df.groupby('reg_indx')

# reg_lognorm_data_size_df= grid_size_pred_func(mdn_model= mdn_lognorm_size_model, stat_model= lognorm_model, max_size_arr= max_fire_train_arr, sum_size_arr= sum_fire_train_arr, \
#                         start_month= 0, final_month= 444, freq_flag= 'data', ml_freq_flag= False, size_test_df= fire_size_tot, X_size_test_dat= X_sizes_tot, \
#                         debug= False, seed= 13) #lognorm_gpd_model_predict
# reg_lognorm_data_size_groups= reg_lognorm_data_size_df.groupby('reg_indx')
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 18/18 [00:48<00:00,  2.68s/it]

# %%
reg_gpd_gpd_tot_size_df= 0.5*(reg_gpd_ext_data_size_df + reg_gpd_data_size_df)
reg_gpd_lognorm_tot_size_df= 0.5*(reg_gpd_ext_data_size_df + reg_lognorm_data_size_df)
#reg_gpd_gpd_logmean_df= reg_gpd_ext_data_size_df.copy()
#reg_gpd_gpd_logmean_df.loc[list(reg_gpd_data_size_df['mean_size'][reg_gpd_data_size_df['mean_size'] != 0].index), 'mean_size']= \
#                10**(0.5*(np.log10(reg_gpd_ext_data_size_df['mean_size'][reg_gpd_ext_data_size_df['mean_size'] != 0]) + np.log10(reg_lognorm_data_size_df['mean_size'][reg_lognorm_data_size_df['mean_size'] != 0])))

reg_gpd_gpd_tot_size_df= reg_gpd_gpd_tot_size_df.astype({'reg_indx': 'int64'})
reg_gpd_lognorm_tot_size_df= reg_gpd_lognorm_tot_size_df.astype({'reg_indx': 'int64'})
reg_gpd_gpd_tot_size_groups= reg_gpd_gpd_tot_size_df.groupby('reg_indx')
reg_gpd_lognorm_tot_size_groups= reg_gpd_lognorm_tot_size_df.groupby('reg_indx')

# %%
largefreq_df= pd.read_hdf('../sav_files/large_fire_freq_scale_fac_df.h5')
mllargefreq_arr= []
for m in tqdm(range(tot_months)):
    mllargefreq_arr.append(np.sum([mdn_mon_freq_groups.get_group(r+1)['pred_mean_freq'].loc[[m]].to_numpy()*largefreq_df.groupby('reg_indx').get_group(r+1)['obs_freq_scale_fac'].loc[[m]].to_numpy() \
                                                       for r in range(18)]))
mllargefreq_ann_arr= np.array([np.sum(mllargefreq_arr[yr_arr[i]:yr_arr[i+1]]) for i in range(len(yr_arr)-1)])
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 444/444 [00:03<00:00, 113.68it/s]

# %%
obslargefreq_arr= []
for m in tqdm(range(tot_months)):
    try:
        indarr= fire_size_tot.groupby('fire_month').get_group(m)
        obslargefreq_arr.append(len(indarr))
    except:
        obslargefreq_arr.append(0)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 444/444 [00:00<00:00, 1722.87it/s]

# %%
obslargefreq_ann_arr= np.array([np.sum(obslargefreq_arr[yr_arr[i]:yr_arr[i+1]]) for i in range(len(yr_arr)-1)])

# %%
plt.plot(yr_arr[:-1], mllargefreq_ann_arr, color= 'black')
plt.plot(yr_arr[:-1], obslargefreq_ann_arr, color= 'red')
